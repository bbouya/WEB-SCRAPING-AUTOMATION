# %%
import pandas as pd

# %%
df_jobs.loc[0]
# Out:
# Unnamed: 0                                                    0
# Title                                            GIS Technician
# Company                 Government of the Northwest Territories
# Location                                             Inuvik, NT
# Link          https://ca.indeed.com/rc/clk?jk=3d7110ce30f15d...
# Review                                                      3,8
# Name: 0, dtype: object

# %%
df_jobs
# Out:
#     Unnamed: 0                                              Title  \
# 0            0                                     GIS Technician
# 1            1                                 Junior GIS Analyst
# 2            2                  nouveau\nSTO 18R - GIS Technician
# 3            3                               nouveau\nGIS Analyst
# 4            4                                     GIS Technician
# 5            5            nouveau\nMeteorologist & GIS Specialist
# 6            6                                     GIS Technician
# 7            7      nouveau\nGIS Technician/Environmental Planner
# 8            8                         nouveau\nGIS Analyst 21639
# 9            9                                        GIS Analyst
# 10          10                                        GIS Student
# 11          11                  nouveau\nGIS Specialist (22-U003)
# 12          12                                      GIS Drafter 2
# ...
